# %%
import numpy as np
from scipy.linalg import svd
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataframe = pd.read_csv("new-jersey-history.csv")
print(dataframe.keys())
print(dataframe)
# Out:
# Index(['date', 'state', 'death', 'deathConfirmed', 'deathIncrease',
#        'deathProbable', 'hospitalized', 'hospitalizedCumulative',
#        'hospitalizedCurrently', 'hospitalizedIncrease', 'inIcuCumulative',
#        'inIcuCurrently', 'negative', 'negativeIncrease',
#        'negativeTestsAntibody', 'negativeTestsPeopleAntibody',
#        'negativeTestsViral', 'onVentilatorCumulative', 'onVentilatorCurrently',
#        'positive', 'positiveCasesViral', 'positiveIncrease', 'positiveScore',
#        'positiveTestsAntibody', 'positiveTestsAntigen',
#        'positiveTestsPeopleAntibody', 'positiveTestsPeopleAntigen',
#        'positiveTestsViral', 'recovered', 'totalTestEncountersViral',
#        'totalTestEncountersViralIncrease', 'totalTestResults',
#        'totalTestResultsIncrease', 'totalTestsAntibody', 'totalTestsAntigen',
#        'totalTestsPeopleAntibody', 'totalTestsPeopleAntigen',
#        'totalTestsPeopleViral', 'totalTestsPeopleViralIncrease',
#        'totalTestsViral', 'totalTestsViralIncrease'],
#       dtype='object')
#            date state  death  deathConfirmed  deathIncrease  deathProbable  \
# 0    2021-03-07    NJ  23574         21177.0             17           2397
# 1    2021-03-06    NJ  23557         21160.0             36           2397
# 2    2021-03-05    NJ  23521         21124.0             30           2397
# 3    2021-03-04    NJ  23491         21094.0             42           2397
# 4    2021-03-03    NJ  23449         21052.0            128           2397
# ..          ...   ...    ...             ...            ...            ...
# 387  2020-02-14    NJ      0             NaN              0              0
# 388  2020-02-13    NJ      0             NaN              0              0
# 389  2020-02-12    NJ      0             NaN              0              0
# 390  2020-02-11    NJ      0             NaN              0              0
# 391  2020-02-10    NJ      0             NaN              0              0
#
#      hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0         64396.0                 64396.0                 1792.0
# 1         64338.0                 64338.0                 1862.0
# 2         65254.0                 65254.0                 1881.0
# 3         64137.0                 64137.0                 1900.0
# 4         64050.0                 64050.0                 1921.0
# ..            ...                     ...                    ...
# 387           NaN                     NaN                    NaN
# 388           NaN                     NaN                    NaN
# 389           NaN                     NaN                    NaN
# 390           NaN                     NaN                    NaN
# 391           NaN                     NaN                    NaN
#
#      hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# 0                      58  ...          10999550                      2519
# 1                    -916  ...          10997031                      3720
# 2                    1117  ...          10993311                     94291
# 3                      87  ...          10899020                      3193
# 4                     133  ...          10895827                    116516
# ..                    ...  ...               ...                       ...
# 387                     0  ...                 0                         0
# 388                     0  ...                 0                         0
# 389                     0  ...                 0                         0
# 390                     0  ...                 0                         0
# 391                     0  ...                 0                         0
#
#      totalTestsAntibody  totalTestsAntigen  totalTestsPeopleAntibody  \
# 0                   NaN                NaN                       NaN
# 1                   NaN                NaN                       NaN
# 2                   NaN                NaN                       NaN
# 3                   NaN                NaN                       NaN
# 4                   NaN                NaN                       NaN
# ..                  ...                ...                       ...
# 387                 NaN                NaN                       NaN
# 388                 NaN                NaN                       NaN
# 389                 NaN                NaN                       NaN
# 390                 NaN                NaN                       NaN
# 391                 NaN                NaN                       NaN
#
#      totalTestsPeopleAntigen  totalTestsPeopleViral  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# ..                       ...                    ...
# 387                      NaN                    NaN
# 388                      NaN                    NaN
# 389                      NaN                    NaN
# 390                      NaN                    NaN
# 391                      NaN                    NaN
#
#      totalTestsPeopleViralIncrease  totalTestsViral  totalTestsViralIncrease
# 0                                0       10902830.0                        0
# 1                                0       10902830.0                        0
# 2                                0       10902830.0                    96433
# 3                                0       10806397.0                        0
# 4                                0       10806397.0                   115772
# ..                             ...              ...                      ...
# 387                              0              NaN                        0
# 388                              0              NaN                        0
# 389                              0              NaN                        0
# 390                              0              NaN                        0
# 391                              0              NaN                        0
#
# [392 rows x 41 columns]

# %%
plt.figure(figsize=(10, 10))
plt.plot(np.array(dataframe["positiveCasesViral"])[::-1], label="+ cases viral")
plt.plot(np.array(dataframe["positiveTestsViral"])[::-1], label="+ tests viral")
plt.legend()
plt.show()

plt.figure(figsize=(10, 10))
#plt.plot(np.array(dataframe["hospitalizedIncrease"])[::-1], label="hospitalized inc.")
plt.plot(np.array(dataframe["positiveIncrease"])[::-1], label="+ inc.")
plt.legend()
plt.show()

plt.figure(figsize=(10, 10))
plt.plot(np.array(dataframe["positiveCasesViral"])[::-1]/np.array(dataframe["totalTestResults"])[::-1], 
         label="+ cases viral per total tests")
#plt.plot(np.array(dataframe["totalTestResults"])[::-1], label="total cases")
plt.legend()
plt.show()

plt.figure(figsize=(10, 10))
plt.plot(np.array(dataframe["totalTestResults"])[::-1], 
         label="+ total tests")
#plt.plot(np.array(dataframe["totalTestResults"])[::-1], label="total cases")
plt.legend()
plt.show()

# %%
date = np.array(dataframe["date"][::-1])
pos_cases = np.array(dataframe["positive"][::-1])

differences = pos_cases[1:] - pos_cases[:-1]
second_differences = differences[1:] - differences[:-1]
trim = 350

plt.figure(figsize=(10, 10))
plt.plot(pos_cases[:trim], "*")
#plt.xlabel("no. cases + ")
plt.ylabel("no. pos cases")
plt.show()

plt.figure(figsize=(10, 10))
plt.plot(differences[14:trim+14], "*")
#plt.xlabel("no. cases + ")
plt.ylabel("no. new cases")
plt.show()

moving_average_current_infected = np.convolve(np.ones(14), differences)
moving_average_infection_rate = np.convolve(np.ones(14), second_differences)
plt.figure(figsize=(10, 10))
plt.plot(pos_cases[:trim], moving_average_current_infected[14:trim+14], "*")
plt.xlabel("positive cases")
plt.ylabel("$d / dt$")
plt.show()

# %%
averaged_rate = moving_average_current_infected[14:trim+14] - moving_average_current_infected[:trim]
plt.figure(figsize=(10, 10))
plt.plot(moving_average_current_infected[14:trim+14], 
         averaged_rate, "*-")
plt.xlabel("d/dt")
plt.ylabel("$d^2 / dt^2$")
plt.show()

print(np.argmax(np.nan_to_num(averaged_rate)))
print(np.argmin(np.nan_to_num(averaged_rate)))
print(date[43])
print(date[82])
# Out:
# 43
# 82
# 2020-03-24
# 2020-05-02

# %%
print(date[50])
print(date[100])
print(date[200])
print(date[214])
# Out:
# 2020-03-31
# 2020-05-20
# 2020-08-28
# 2020-09-11

# %%
data = np.zeros([trim, 3])
data[:, 0] = pos_cases[:trim]
data[:, 1] = moving_average_current_infected[14:trim+14]
data[:, 2] = moving_average_current_infected[28:trim+28] - moving_average_current_infected[14:trim+14]
data = np.nan_to_num(data)
u, s, v = np.linalg.svd(data)
print(s)
print(np.shape(u))
print(np.shape(v))

plt.plot(u[:, 1], u[:, 2])
# Out:
# [4987404.37257863  365061.47819429  227783.61416965]
# (350, 350)
# (3, 3)

# %%
from sklearn.cluster import KMeans

# %%
n = len(subframe["positiveCasesViral"])
X = np.zeros([n, 2])
X[:, 0] = np.array(subframe["positiveCasesViral"])
X[:, 1] = np.array(subframe["positiveIncrease"])
Y = -(X[1:, :] - X[:-1, :])

fitter = KMeans(n_clusters=2)
fitter.fit(Y)
# Out:
# KMeans(n_clusters=2)

# %%
plt.figure(figsize=(10, 10))
plt.plot(Y[-50:, 0], Y[-50:, 1], "*")
plt.plot(Y[-100:-50, 0], Y[-100:-50, 1], "*")
plt.plot(Y[-200:-100, 0], Y[-200:-100, 1], "*")
#plt.plot(Y[:-200, 0], Y[:-200, 1], "*")

plt.plot(fitter.cluster_centers_[:, 0], fitter.cluster_centers_[:, 1], "^", 
        markersize=10)
plt.xlabel("positive cases")
plt.ylabel("$d / dt$")
plt.show()

# %%
from scipy.integrate import solve_ivp
def fun(t, x, a, b):
    ddt = np.zeros(3)
    ddt[0] = -a * x[0] * x[1]
    ddt[1] = -ddt[0] - b * x[1]
    ddt[2] = b * x[1]
    return ddt

init = np.array([1, 0.001, 0])
params = [0.2, 0.05]
sol = solve_ivp(fun, [0, 300], init, args=params, max_step=0.5)
plt.plot(sol.t, sol.y[1, :])
plt.show()

# %%
# %matplotlib inline
plt.plot(sol.y[1, :-1], sol.y[1, 1:] - sol.y[1, :-1], "*")
plt.show()

# %%
# %matplotlib notebook
trim = 350
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(projection='3d')
ax.plot(pos_cases[14:trim+14], moving_average_current_infected[14:trim+14], 
         moving_average_current_infected[14:trim+14] - moving_average_current_infected[:trim], "*")
ax.set_xlabel("no cases")
ax.set_ylabel("$d / dt$")
ax.set_zlabel("$d^2 / dt^2$")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="360">
# <img src="data:image/png;base64,..." width="360">
